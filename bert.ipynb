# %%
import pandas as pd

# %%
from transformers import pipeline

# %%
df = pd.read_csv(r'C:\Users\lenovo\Downloads\g_reviews.csv')

# %%
df.head()
# Out:
#                                           ReviewText  Sentiment
# 0              Review #1: Highly disappointing read.          0
# 1  Review #2: A page-turner with a powerful message.          2
# 2          Review #3: A masterpiece of storytelling.          2
# 3        Review #4: Heartwarming and inspiring read.          2
# 4        Review #5: Neither good nor bad, just fine.          1

# %%
df.shape
# Out:
# (1209, 2)

# %%
print(df.isnull().sum())
# Out:
# ReviewText    0
# Sentiment     0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
classifier = pipeline("sentiment-analysis", model ="cardiffnlp/twitter-roberta-base-sentiment")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
reviews = df['ReviewText'].iloc[10:20]

# %%
for i in reviews:

    result = classifier(i)

    label = result[0]['label']
    score = result[0]['score']

    if label == 'LABEL_0':
        sentiment = "Negative"
    
    elif label == 'LABEL_1':
        sentiment = "Neutral"

    else:
        sentiment = "Positive"

    print("Review :")
    print(i)

    print("\nPredicted Sentiment : ", sentiment)
    print("predicted Confidence Score :", round(score,3))

    print("-"*75)
# Out:
# Review :
# Review #11: Plain narrative, suitable for casual reading.
#
# Predicted Sentiment :  Positive
# predicted Confidence Score : 0.551
# ---------------------------------------------------------------------------
# Review :
# Review #12: Struggled to stay interested.
#
# Predicted Sentiment :  Negative
# predicted Confidence Score : 0.652
# ---------------------------------------------------------------------------
# Review :
# Review #13: Had its moments, but not remarkable.
#
# Predicted Sentiment :  Negative
# predicted Confidence Score : 0.628
# ---------------------------------------------------------------------------
# Review :
# Review #14: Neither good nor bad, just fine.
#
# Predicted Sentiment :  Positive
# predicted Confidence Score : 0.842
# ---------------------------------------------------------------------------
# Review :
# Review #15: Terrible writing, couldn't finish it.
#
# Predicted Sentiment :  Negative
# predicted Confidence Score : 0.969
# ---------------------------------------------------------------------------
# Review :
# Review #16: Plain narrative, suitable for casual reading.
#
# Predicted Sentiment :  Positive
# predicted Confidence Score : 0.527
# ---------------------------------------------------------------------------
# Review :
# Review #17: Average read, nothing memorable.
#
# Predicted Sentiment :  Negative
# predicted Confidence Score : 0.862
# ---------------------------------------------------------------------------
# Review :
# Review #18: It was okay, not too exciting.
#
# Predicted Sentiment :  Neutral
# predicted Confidence Score : 0.449
# ---------------------------------------------------------------------------
# Review :
# Review #19: Uninspiring and boring.
#
# Predicted Sentiment :  Negative
# predicted Confidence Score : 0.958
# ---------------------------------------------------------------------------
# Review :
# Review #20: Did not enjoy the plot.
#
# Predicted Sentiment :  Negative
# predicted Confidence Score : 0.96
# ---------------------------------------------------------------------------

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification

# %%
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
model.save_pretrained('saved_model')
tokenizer.save_pretrained('saved_model')
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ('saved_model\\tokenizer_config.json', 'saved_model\\tokenizer.json')
